# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 945us/sample - loss: 235.3137 - y1_output_loss: 106.4790 - y2_output_loss: 126.8211 - y1_output_root_mean_squared_error: 10.3646 - y2_output_root_mean_squared_error: 11.3088 - val_loss: 51.4403 - val_y1_output_loss: 20.6569 - val_y2_output_loss: 32.0061 - val_y1_output_root_mean_squared_error: 4.4428 - val_y2_output_root_mean_squared_error: 5.6305
# Epoch 2/500
# 614/614 [==============================] - 0s 136us/sample - loss: 32.8190 - y1_output_loss: 12.8171 - y2_output_loss: 20.1541 - y1_output_root_mean_squared_error: 3.5680 - y2_output_root_mean_squared_error: 4.4820 - val_loss: 36.3452 - val_y1_output_loss: 15.1063 - val_y2_output_loss: 22.0631 - val_y1_output_root_mean_squared_error: 3.7888 - val_y2_output_root_mean_squared_error: 4.6893
# Epoch 3/500
# 614/614 [==============================] - 0s 135us/sample - loss: 31.5533 - y1_output_loss: 10.8657 - y2_output_loss: 20.4111 - y1_output_root_mean_squared_error: 3.3120 - y2_output_root_mean_squared_error: 4.5369 - val_loss: 26.9182 - val_y1_output_loss: 11.6900 - val_y2_output_loss: 15.8284 - val_y1_output_root_mean_squared_error: 3.3355 - val_y2_output_root_mean_squared_error: 3.9740
# Epoch 4/500
# 614/614 [==============================] - 0s 129us/sample - loss: 21.5353 - y1_output_loss: 8.3690 - y2_output_loss: 13.0403 - y1_output_root_mean_squared_error: 2.9044 - y2_output_root_mean_squared_error: 3.6194 - val_loss: 25.1517 - val_y1_output_loss: 11.7322 - val_y2_output_loss: 13.4123 - val_y1_output_root_mean_squared_error: 3.3913 - val_y2_output_root_mean_squared_error: 3.6947
# Epoch 5/500
# 614/614 [==============================] - 0s 133us/sample - loss: 23.6092 - y1_output_loss: 9.2354 - y2_output_loss: 14.8553 - y1_output_root_mean_squared_error: 3.0241 - y2_output_root_mean_squared_error: 3.8031 - val_loss: 62.8592 - val_y1_output_loss: 12.3912 - val_y2_output_loss: 48.9911 - val_y1_output_root_mean_squared_error: 3.4966 - val_y2_output_root_mean_squared_error: 7.1157
# Epoch 6/500
# 614/614 [==============================] - 0s 132us/sample - loss: 20.9755 - y1_output_loss: 8.4432 - y2_output_loss: 12.6617 - y1_output_root_mean_squared_error: 2.9010 - y2_output_root_mean_squared_error: 3.5440 - val_loss: 41.1851 - val_y1_output_loss: 12.8691 - val_y2_output_loss: 27.2864 - val_y1_output_root_mean_squared_error: 3.5895 - val_y2_output_root_mean_squared_error: 5.3198
# Epoch 7/500
# 614/614 [==============================] - 0s 132us/sample - loss: 20.8690 - y1_output_loss: 7.9991 - y2_output_loss: 12.8997 - y1_output_root_mean_squared_error: 2.8298 - y2_output_root_mean_squared_error: 3.5863 - val_loss: 33.1239 - val_y1_output_loss: 11.2320 - val_y2_output_loss: 22.4283 - val_y1_output_root_mean_squared_error: 3.2710 - val_y2_output_root_mean_squared_error: 4.7355
# Epoch 8/500
# 614/614 [==============================] - 0s 136us/sample - loss: 19.5212 - y1_output_loss: 7.8572 - y2_output_loss: 11.5385 - y1_output_root_mean_squared_error: 2.8146 - y2_output_root_mean_squared_error: 3.4057 - val_loss: 21.2693 - val_y1_output_loss: 9.1158 - val_y2_output_loss: 12.3699 - val_y1_output_root_mean_squared_error: 2.9597 - val_y2_output_root_mean_squared_error: 3.5368
# Epoch 9/500
# 614/614 [==============================] - 0s 134us/sample - loss: 21.8348 - y1_output_loss: 8.1125 - y2_output_loss: 13.5192 - y1_output_root_mean_squared_error: 2.8616 - y2_output_root_mean_squared_error: 3.6941 - val_loss: 22.7252 - val_y1_output_loss: 10.2564 - val_y2_output_loss: 12.4803 - val_y1_output_root_mean_squared_error: 3.1692 - val_y2_output_root_mean_squared_error: 3.5611
# Epoch 10/500
# 614/614 [==============================] - 0s 131us/sample - loss: 20.8255 - y1_output_loss: 8.1115 - y2_output_loss: 12.5909 - y1_output_root_mean_squared_error: 2.8567 - y2_output_root_mean_squared_error: 3.5587 - val_loss: 20.5192 - val_y1_output_loss: 8.9758 - val_y2_output_loss: 11.5683 - val_y1_output_root_mean_squared_error: 2.9473 - val_y2_output_root_mean_squared_error: 3.4399
# Epoch 11/500
# 614/614 [==============================] - 0s 130us/sample - loss: 19.1248 - y1_output_loss: 7.4746 - y2_output_loss: 11.5433 - y1_output_root_mean_squared_error: 2.7416 - y2_output_root_mean_squared_error: 3.4071 - val_loss: 25.6634 - val_y1_output_loss: 10.5833 - val_y2_output_loss: 14.7778 - val_y1_output_root_mean_squared_error: 3.2305 - val_y2_output_root_mean_squared_error: 3.9022
# Epoch 12/500
# 614/614 [==============================] - 0s 133us/sample - loss: 23.1981 - y1_output_loss: 8.2270 - y2_output_loss: 14.8561 - y1_output_root_mean_squared_error: 2.8774 - y2_output_root_mean_squared_error: 3.8625 - val_loss: 27.6385 - val_y1_output_loss: 9.3119 - val_y2_output_loss: 18.6245 - val_y1_output_root_mean_squared_error: 2.9934 - val_y2_output_root_mean_squared_error: 4.3219
# Epoch 13/500
# 614/614 [==============================] - 0s 136us/sample - loss: 19.6220 - y1_output_loss: 7.5954 - y2_output_loss: 12.2684 - y1_output_root_mean_squared_error: 2.7486 - y2_output_root_mean_squared_error: 3.4738 - val_loss: 82.5681 - val_y1_output_loss: 20.2033 - val_y2_output_loss: 61.9550 - val_y1_output_root_mean_squared_error: 4.4544 - val_y2_output_root_mean_squared_error: 7.9200
# Epoch 14/500
# 614/614 [==============================] - 0s 136us/sample - loss: 20.8105 - y1_output_loss: 7.8090 - y2_output_loss: 12.8658 - y1_output_root_mean_squared_error: 2.8047 - y2_output_root_mean_squared_error: 3.5978 - val_loss: 20.3967 - val_y1_output_loss: 8.5524 - val_y2_output_loss: 11.9246 - val_y1_output_root_mean_squared_error: 2.8821 - val_y2_output_root_mean_squared_error: 3.4771
# Epoch 15/500
# 614/614 [==============================] - 0s 129us/sample - loss: 17.7687 - y1_output_loss: 6.9257 - y2_output_loss: 10.7027 - y1_output_root_mean_squared_error: 2.6394 - y2_output_root_mean_squared_error: 3.2867 - val_loss: 19.9672 - val_y1_output_loss: 9.0449 - val_y2_output_loss: 10.6374 - val_y1_output_root_mean_squared_error: 3.0068 - val_y2_output_root_mean_squared_error: 3.3055
# Epoch 16/500
# 614/614 [==============================] - 0s 133us/sample - loss: 23.1342 - y1_output_loss: 8.1276 - y2_output_loss: 14.8389 - y1_output_root_mean_squared_error: 2.8638 - y2_output_root_mean_squared_error: 3.8643 - val_loss: 30.3550 - val_y1_output_loss: 12.0973 - val_y2_output_loss: 17.5520 - val_y1_output_root_mean_squared_error: 3.5040 - val_y2_output_root_mean_squared_error: 4.2517
# Epoch 17/500
# 614/614 [==============================] - 0s 134us/sample - loss: 20.0284 - y1_output_loss: 7.2468 - y2_output_loss: 12.6719 - y1_output_root_mean_squared_error: 2.6980 - y2_output_root_mean_squared_error: 3.5706 - val_loss: 63.8599 - val_y1_output_loss: 17.3367 - val_y2_output_loss: 44.5262 - val_y1_output_root_mean_squared_error: 4.2229 - val_y2_output_root_mean_squared_error: 6.7843
# Epoch 18/500
# 614/614 [==============================] - 0s 129us/sample - loss: 20.8193 - y1_output_loss: 7.6594 - y2_output_loss: 14.0191 - y1_output_root_mean_squared_error: 2.7294 - y2_output_root_mean_squared_error: 3.6565 - val_loss: 95.3687 - val_y1_output_loss: 21.7783 - val_y2_output_loss: 73.2985 - val_y1_output_root_mean_squared_error: 4.6173 - val_y2_output_root_mean_squared_error: 8.6052
# Epoch 19/500
# 614/614 [==============================] - 0s 130us/sample - loss: 19.4980 - y1_output_loss: 7.3994 - y2_output_loss: 11.9684 - y1_output_root_mean_squared_error: 2.7295 - y2_output_root_mean_squared_error: 3.4710 - val_loss: 25.7581 - val_y1_output_loss: 8.7448 - val_y2_output_loss: 17.1911 - val_y1_output_root_mean_squared_error: 2.8991 - val_y2_output_root_mean_squared_error: 4.1657
# Epoch 20/500
# 614/614 [==============================] - 0s 132us/sample - loss: 17.4853 - y1_output_loss: 6.6655 - y2_output_loss: 10.6903 - y1_output_root_mean_squared_error: 2.5907 - y2_output_root_mean_squared_error: 3.2823 - val_loss: 16.6783 - val_y1_output_loss: 7.3939 - val_y2_output_loss: 9.2658 - val_y1_output_root_mean_squared_error: 2.6760 - val_y2_output_root_mean_squared_error: 3.0850
# Epoch 21/500
# 614/614 [==============================] - 0s 130us/sample - loss: 15.6088 - y1_output_loss: 6.5044 - y2_output_loss: 9.5504 - y1_output_root_mean_squared_error: 2.5155 - y2_output_root_mean_squared_error: 3.0465 - val_loss: 65.9597 - val_y1_output_loss: 16.3783 - val_y2_output_loss: 49.4854 - val_y1_output_root_mean_squared_error: 3.9914 - val_y2_output_root_mean_squared_error: 7.0731
# Epoch 22/500
# 614/614 [==============================] - 0s 131us/sample - loss: 17.0759 - y1_output_loss: 6.5265 - y2_output_loss: 10.4627 - y1_output_root_mean_squared_error: 2.5526 - y2_output_root_mean_squared_error: 3.2496 - val_loss: 18.9146 - val_y1_output_loss: 9.4656 - val_y2_output_loss: 8.9461 - val_y1_output_root_mean_squared_error: 3.1099 - val_y2_output_root_mean_squared_error: 3.0403
# Epoch 23/500
# 614/614 [==============================] - 0s 132us/sample - loss: 17.2904 - y1_output_loss: 6.4538 - y2_output_loss: 10.8047 - y1_output_root_mean_squared_error: 2.5330 - y2_output_root_mean_squared_error: 3.2976 - val_loss: 18.1938 - val_y1_output_loss: 7.4671 - val_y2_output_loss: 10.5836 - val_y1_output_root_mean_squared_error: 2.7093 - val_y2_output_root_mean_squared_error: 3.2945
# Epoch 24/500
# 614/614 [==============================] - 0s 129us/sample - loss: 14.7903 - y1_output_loss: 5.7096 - y2_output_loss: 9.0299 - y1_output_root_mean_squared_error: 2.3827 - y2_output_root_mean_squared_error: 3.0188 - val_loss: 15.8981 - val_y1_output_loss: 7.0450 - val_y2_output_loss: 8.5561 - val_y1_output_root_mean_squared_error: 2.6627 - val_y2_output_root_mean_squared_error: 2.9679
# Epoch 25/500
# 614/614 [==============================] - 0s 129us/sample - loss: 15.0344 - y1_output_loss: 5.8270 - y2_output_loss: 9.0950 - y1_output_root_mean_squared_error: 2.4242 - y2_output_root_mean_squared_error: 3.0261 - val_loss: 25.8142 - val_y1_output_loss: 9.4807 - val_y2_output_loss: 15.6517 - val_y1_output_root_mean_squared_error: 3.1124 - val_y2_output_root_mean_squared_error: 4.0159
# Epoch 26/500
# 614/614 [==============================] - 0s 132us/sample - loss: 16.1628 - y1_output_loss: 6.0784 - y2_output_loss: 9.9836 - y1_output_root_mean_squared_error: 2.4744 - y2_output_root_mean_squared_error: 3.1686 - val_loss: 14.3174 - val_y1_output_loss: 5.8782 - val_y2_output_loss: 8.1863 - val_y1_output_root_mean_squared_error: 2.4149 - val_y2_output_root_mean_squared_error: 2.9130
# Epoch 27/500
# 614/614 [==============================] - 0s 137us/sample - loss: 16.3439 - y1_output_loss: 5.9699 - y2_output_loss: 10.6432 - y1_output_root_mean_squared_error: 2.4227 - y2_output_root_mean_squared_error: 3.2364 - val_loss: 47.4406 - val_y1_output_loss: 16.3078 - val_y2_output_loss: 30.3731 - val_y1_output_root_mean_squared_error: 4.0395 - val_y2_output_root_mean_squared_error: 5.5788
# Epoch 28/500
# 614/614 [==============================] - 0s 130us/sample - loss: 15.1337 - y1_output_loss: 5.8128 - y2_output_loss: 9.2019 - y1_output_root_mean_squared_error: 2.4202 - y2_output_root_mean_squared_error: 3.0457 - val_loss: 14.1486 - val_y1_output_loss: 5.9117 - val_y2_output_loss: 8.0207 - val_y1_output_root_mean_squared_error: 2.4205 - val_y2_output_root_mean_squared_error: 2.8792
# Epoch 29/500
# 614/614 [==============================] - 0s 131us/sample - loss: 15.9959 - y1_output_loss: 5.5187 - y2_output_loss: 10.3789 - y1_output_root_mean_squared_error: 2.3565 - y2_output_root_mean_squared_error: 3.2315 - val_loss: 12.2235 - val_y1_output_loss: 5.1252 - val_y2_output_loss: 6.9258 - val_y1_output_root_mean_squared_error: 2.2519 - val_y2_output_root_mean_squared_error: 2.6744
# Epoch 30/500
# 614/614 [==============================] - 0s 127us/sample - loss: 12.9571 - y1_output_loss: 4.7732 - y2_output_loss: 8.0698 - y1_output_root_mean_squared_error: 2.1939 - y2_output_root_mean_squared_error: 2.8537 - val_loss: 12.1332 - val_y1_output_loss: 4.8040 - val_y2_output_loss: 7.0419 - val_y1_output_root_mean_squared_error: 2.1992 - val_y2_output_root_mean_squared_error: 2.7012
# Epoch 31/500
# 614/614 [==============================] - 0s 134us/sample - loss: 13.9270 - y1_output_loss: 4.9755 - y2_output_loss: 8.8552 - y1_output_root_mean_squared_error: 2.2377 - y2_output_root_mean_squared_error: 2.9866 - val_loss: 15.9642 - val_y1_output_loss: 5.5810 - val_y2_output_loss: 10.3112 - val_y1_output_root_mean_squared_error: 2.3326 - val_y2_output_root_mean_squared_error: 3.2440
# Epoch 32/500
# 614/614 [==============================] - 0s 128us/sample - loss: 13.6981 - y1_output_loss: 5.0006 - y2_output_loss: 8.5909 - y1_output_root_mean_squared_error: 2.2454 - y2_output_root_mean_squared_error: 2.9422 - val_loss: 11.6200 - val_y1_output_loss: 4.7707 - val_y2_output_loss: 6.6501 - val_y1_output_root_mean_squared_error: 2.1837 - val_y2_output_root_mean_squared_error: 2.6175
# Epoch 33/500
# 614/614 [==============================] - 0s 128us/sample - loss: 16.2524 - y1_output_loss: 5.5061 - y2_output_loss: 10.6300 - y1_output_root_mean_squared_error: 2.3548 - y2_output_root_mean_squared_error: 3.2722 - val_loss: 12.1402 - val_y1_output_loss: 4.9620 - val_y2_output_loss: 6.9433 - val_y1_output_root_mean_squared_error: 2.2342 - val_y2_output_root_mean_squared_error: 2.6737
# Epoch 34/500
# 614/614 [==============================] - 0s 127us/sample - loss: 11.9723 - y1_output_loss: 4.2206 - y2_output_loss: 7.6626 - y1_output_root_mean_squared_error: 2.0615 - y2_output_root_mean_squared_error: 2.7790 - val_loss: 11.7645 - val_y1_output_loss: 4.8339 - val_y2_output_loss: 6.6561 - val_y1_output_root_mean_squared_error: 2.2105 - val_y2_output_root_mean_squared_error: 2.6227
# Epoch 35/500
# 614/614 [==============================] - 0s 135us/sample - loss: 11.5834 - y1_output_loss: 4.5203 - y2_output_loss: 6.9898 - y1_output_root_mean_squared_error: 2.1290 - y2_output_root_mean_squared_error: 2.6553 - val_loss: 13.6262 - val_y1_output_loss: 5.3562 - val_y2_output_loss: 7.8889 - val_y1_output_root_mean_squared_error: 2.3478 - val_y2_output_root_mean_squared_error: 2.8485
# Epoch 36/500
# 614/614 [==============================] - 0s 133us/sample - loss: 11.2842 - y1_output_loss: 4.1101 - y2_output_loss: 7.0703 - y1_output_root_mean_squared_error: 2.0363 - y2_output_root_mean_squared_error: 2.6717 - val_loss: 10.0982 - val_y1_output_loss: 4.1050 - val_y2_output_loss: 5.7128 - val_y1_output_root_mean_squared_error: 2.0436 - val_y2_output_root_mean_squared_error: 2.4335
# Epoch 37/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.4082 - y1_output_loss: 3.5826 - y2_output_loss: 5.9223 - y1_output_root_mean_squared_error: 1.8863 - y2_output_root_mean_squared_error: 2.4187 - val_loss: 11.0647 - val_y1_output_loss: 4.5950 - val_y2_output_loss: 6.1879 - val_y1_output_root_mean_squared_error: 2.1591 - val_y2_output_root_mean_squared_error: 2.5304
# Epoch 38/500
# 614/614 [==============================] - 0s 134us/sample - loss: 10.7226 - y1_output_loss: 3.8787 - y2_output_loss: 6.8437 - y1_output_root_mean_squared_error: 1.9640 - y2_output_root_mean_squared_error: 2.6202 - val_loss: 18.2231 - val_y1_output_loss: 6.3367 - val_y2_output_loss: 11.6435 - val_y1_output_root_mean_squared_error: 2.5025 - val_y2_output_root_mean_squared_error: 3.4584
# Epoch 39/500
# 614/614 [==============================] - 0s 131us/sample - loss: 10.2459 - y1_output_loss: 3.7522 - y2_output_loss: 6.4555 - y1_output_root_mean_squared_error: 1.9387 - y2_output_root_mean_squared_error: 2.5470 - val_loss: 9.1804 - val_y1_output_loss: 3.8075 - val_y2_output_loss: 5.1017 - val_y1_output_root_mean_squared_error: 1.9769 - val_y2_output_root_mean_squared_error: 2.2962
# Epoch 40/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.5059 - y1_output_loss: 3.2960 - y2_output_loss: 6.3299 - y1_output_root_mean_squared_error: 1.8143 - y2_output_root_mean_squared_error: 2.4929 - val_loss: 27.8120 - val_y1_output_loss: 7.4270 - val_y2_output_loss: 19.9103 - val_y1_output_root_mean_squared_error: 2.7170 - val_y2_output_root_mean_squared_error: 4.5200
# Epoch 41/500
# 614/614 [==============================] - 0s 130us/sample - loss: 9.1533 - y1_output_loss: 3.1121 - y2_output_loss: 5.9905 - y1_output_root_mean_squared_error: 1.7722 - y2_output_root_mean_squared_error: 2.4521 - val_loss: 9.7533 - val_y1_output_loss: 3.2607 - val_y2_output_loss: 6.2905 - val_y1_output_root_mean_squared_error: 1.8189 - val_y2_output_root_mean_squared_error: 2.5387
# Epoch 42/500
# 614/614 [==============================] - 0s 132us/sample - loss: 11.0454 - y1_output_loss: 3.5074 - y2_output_loss: 7.4533 - y1_output_root_mean_squared_error: 1.8768 - y2_output_root_mean_squared_error: 2.7428 - val_loss: 8.4538 - val_y1_output_loss: 3.2310 - val_y2_output_loss: 5.0276 - val_y1_output_root_mean_squared_error: 1.8005 - val_y2_output_root_mean_squared_error: 2.2830
# Epoch 43/500
# 614/614 [==============================] - 0s 129us/sample - loss: 8.3267 - y1_output_loss: 2.6821 - y2_output_loss: 5.5714 - y1_output_root_mean_squared_error: 1.6442 - y2_output_root_mean_squared_error: 2.3713 - val_loss: 9.3522 - val_y1_output_loss: 3.7675 - val_y2_output_loss: 5.3381 - val_y1_output_root_mean_squared_error: 1.9698 - val_y2_output_root_mean_squared_error: 2.3393
# Epoch 44/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.8016 - y1_output_loss: 2.7426 - y2_output_loss: 5.0915 - y1_output_root_mean_squared_error: 1.6466 - y2_output_root_mean_squared_error: 2.2562 - val_loss: 7.7627 - val_y1_output_loss: 3.1305 - val_y2_output_loss: 4.5156 - val_y1_output_root_mean_squared_error: 1.7748 - val_y2_output_root_mean_squared_error: 2.1478
# Epoch 45/500
# 614/614 [==============================] - 0s 130us/sample - loss: 8.8479 - y1_output_loss: 3.1049 - y2_output_loss: 5.6889 - y1_output_root_mean_squared_error: 1.7631 - y2_output_root_mean_squared_error: 2.3957 - val_loss: 7.0122 - val_y1_output_loss: 2.6580 - val_y2_output_loss: 4.2190 - val_y1_output_root_mean_squared_error: 1.6291 - val_y2_output_root_mean_squared_error: 2.0876
# Epoch 46/500
# 614/614 [==============================] - 0s 132us/sample - loss: 8.4619 - y1_output_loss: 2.4950 - y2_output_loss: 5.9258 - y1_output_root_mean_squared_error: 1.5864 - y2_output_root_mean_squared_error: 2.4383 - val_loss: 11.0472 - val_y1_output_loss: 2.9772 - val_y2_output_loss: 7.8895 - val_y1_output_root_mean_squared_error: 1.7437 - val_y2_output_root_mean_squared_error: 2.8296
# Epoch 47/500
# 614/614 [==============================] - 0s 130us/sample - loss: 7.0034 - y1_output_loss: 2.4118 - y2_output_loss: 4.6591 - y1_output_root_mean_squared_error: 1.5309 - y2_output_root_mean_squared_error: 2.1586 - val_loss: 7.8951 - val_y1_output_loss: 3.0943 - val_y2_output_loss: 4.6426 - val_y1_output_root_mean_squared_error: 1.7639 - val_y2_output_root_mean_squared_error: 2.1872
# Epoch 48/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.8869 - y1_output_loss: 2.2761 - y2_output_loss: 4.5956 - y1_output_root_mean_squared_error: 1.5154 - y2_output_root_mean_squared_error: 2.1425 - val_loss: 7.5576 - val_y1_output_loss: 2.5674 - val_y2_output_loss: 4.8639 - val_y1_output_root_mean_squared_error: 1.6242 - val_y2_output_root_mean_squared_error: 2.2180
# Epoch 49/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.5010 - y1_output_loss: 2.1579 - y2_output_loss: 4.3251 - y1_output_root_mean_squared_error: 1.4712 - y2_output_root_mean_squared_error: 2.0824 - val_loss: 17.8852 - val_y1_output_loss: 3.6891 - val_y2_output_loss: 14.0348 - val_y1_output_root_mean_squared_error: 1.9542 - val_y2_output_root_mean_squared_error: 3.7505
# Epoch 50/500
# 614/614 [==============================] - 0s 130us/sample - loss: 8.2868 - y1_output_loss: 2.4758 - y2_output_loss: 5.7992 - y1_output_root_mean_squared_error: 1.5736 - y2_output_root_mean_squared_error: 2.4105 - val_loss: 8.6560 - val_y1_output_loss: 2.1144 - val_y2_output_loss: 6.4903 - val_y1_output_root_mean_squared_error: 1.4594 - val_y2_output_root_mean_squared_error: 2.5546
# Epoch 51/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.1817 - y1_output_loss: 1.8468 - y2_output_loss: 4.3091 - y1_output_root_mean_squared_error: 1.3574 - y2_output_root_mean_squared_error: 2.0831 - val_loss: 6.0706 - val_y1_output_loss: 2.4414 - val_y2_output_loss: 3.4783 - val_y1_output_root_mean_squared_error: 1.5877 - val_y2_output_root_mean_squared_error: 1.8841
# Epoch 52/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.3389 - y1_output_loss: 1.6296 - y2_output_loss: 3.7254 - y1_output_root_mean_squared_error: 1.2714 - y2_output_root_mean_squared_error: 1.9293 - val_loss: 9.4230 - val_y1_output_loss: 2.7837 - val_y2_output_loss: 6.5690 - val_y1_output_root_mean_squared_error: 1.6998 - val_y2_output_root_mean_squared_error: 2.5561
# Epoch 53/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.1278 - y1_output_loss: 1.7706 - y2_output_loss: 4.3245 - y1_output_root_mean_squared_error: 1.3364 - y2_output_root_mean_squared_error: 2.0837 - val_loss: 5.7363 - val_y1_output_loss: 1.7869 - val_y2_output_loss: 3.8840 - val_y1_output_root_mean_squared_error: 1.3502 - val_y2_output_root_mean_squared_error: 1.9782
# Epoch 54/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.9720 - y1_output_loss: 2.0764 - y2_output_loss: 4.8448 - y1_output_root_mean_squared_error: 1.4470 - y2_output_root_mean_squared_error: 2.2087 - val_loss: 6.8315 - val_y1_output_loss: 2.6182 - val_y2_output_loss: 4.0241 - val_y1_output_root_mean_squared_error: 1.6420 - val_y2_output_root_mean_squared_error: 2.0336
# Epoch 55/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.3721 - y1_output_loss: 1.6261 - y2_output_loss: 3.7572 - y1_output_root_mean_squared_error: 1.2795 - y2_output_root_mean_squared_error: 1.9326 - val_loss: 5.2041 - val_y1_output_loss: 1.5400 - val_y2_output_loss: 3.6261 - val_y1_output_root_mean_squared_error: 1.2545 - val_y2_output_root_mean_squared_error: 1.9053
# Epoch 56/500
# 614/614 [==============================] - 0s 134us/sample - loss: 5.5019 - y1_output_loss: 1.4618 - y2_output_loss: 3.9970 - y1_output_root_mean_squared_error: 1.2133 - y2_output_root_mean_squared_error: 2.0075 - val_loss: 6.0294 - val_y1_output_loss: 1.9239 - val_y2_output_loss: 3.9765 - val_y1_output_root_mean_squared_error: 1.4028 - val_y2_output_root_mean_squared_error: 2.0153
# Epoch 57/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.3225 - y1_output_loss: 2.2563 - y2_output_loss: 5.0779 - y1_output_root_mean_squared_error: 1.4975 - y2_output_root_mean_squared_error: 2.2539 - val_loss: 15.8808 - val_y1_output_loss: 4.1271 - val_y2_output_loss: 11.2809 - val_y1_output_root_mean_squared_error: 2.0497 - val_y2_output_root_mean_squared_error: 3.4175
# Epoch 58/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.7706 - y1_output_loss: 2.1013 - y2_output_loss: 4.6326 - y1_output_root_mean_squared_error: 1.4473 - y2_output_root_mean_squared_error: 2.1624 - val_loss: 4.5750 - val_y1_output_loss: 1.4672 - val_y2_output_loss: 3.0180 - val_y1_output_root_mean_squared_error: 1.2313 - val_y2_output_root_mean_squared_error: 1.7490
# Epoch 59/500
# 614/614 [==============================] - 0s 141us/sample - loss: 5.2816 - y1_output_loss: 1.4449 - y2_output_loss: 3.7953 - y1_output_root_mean_squared_error: 1.2042 - y2_output_root_mean_squared_error: 1.9574 - val_loss: 4.2918 - val_y1_output_loss: 1.3265 - val_y2_output_loss: 2.9197 - val_y1_output_root_mean_squared_error: 1.1637 - val_y2_output_root_mean_squared_error: 1.7139
# Epoch 60/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.4470 - y1_output_loss: 1.4708 - y2_output_loss: 3.9717 - y1_output_root_mean_squared_error: 1.2063 - y2_output_root_mean_squared_error: 1.9980 - val_loss: 12.7906 - val_y1_output_loss: 4.2490 - val_y2_output_loss: 8.1656 - val_y1_output_root_mean_squared_error: 2.0776 - val_y2_output_root_mean_squared_error: 2.9110
# Epoch 61/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.5671 - y1_output_loss: 1.3041 - y2_output_loss: 3.2629 - y1_output_root_mean_squared_error: 1.1450 - y2_output_root_mean_squared_error: 1.8045 - val_loss: 5.6707 - val_y1_output_loss: 1.6570 - val_y2_output_loss: 3.8725 - val_y1_output_root_mean_squared_error: 1.2981 - val_y2_output_root_mean_squared_error: 1.9964
# Epoch 62/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.4733 - y1_output_loss: 1.3158 - y2_output_loss: 4.1270 - y1_output_root_mean_squared_error: 1.1476 - y2_output_root_mean_squared_error: 2.0387 - val_loss: 6.0319 - val_y1_output_loss: 1.3622 - val_y2_output_loss: 4.4985 - val_y1_output_root_mean_squared_error: 1.1823 - val_y2_output_root_mean_squared_error: 2.1527
# Epoch 63/500
# 614/614 [==============================] - 0s 141us/sample - loss: 5.6856 - y1_output_loss: 1.3941 - y2_output_loss: 4.2541 - y1_output_root_mean_squared_error: 1.1864 - y2_output_root_mean_squared_error: 2.0683 - val_loss: 5.9062 - val_y1_output_loss: 1.6761 - val_y2_output_loss: 4.1851 - val_y1_output_root_mean_squared_error: 1.3161 - val_y2_output_root_mean_squared_error: 2.0430
# Epoch 64/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.4373 - y1_output_loss: 1.1007 - y2_output_loss: 3.4664 - y1_output_root_mean_squared_error: 1.0427 - y2_output_root_mean_squared_error: 1.8303 - val_loss: 39.1365 - val_y1_output_loss: 6.7114 - val_y2_output_loss: 31.3559 - val_y1_output_root_mean_squared_error: 2.6106 - val_y2_output_root_mean_squared_error: 5.6852
# Epoch 65/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.5368 - y1_output_loss: 1.2668 - y2_output_loss: 3.2448 - y1_output_root_mean_squared_error: 1.1233 - y2_output_root_mean_squared_error: 1.8097 - val_loss: 3.6882 - val_y1_output_loss: 0.9647 - val_y2_output_loss: 2.6888 - val_y1_output_root_mean_squared_error: 0.9992 - val_y2_output_root_mean_squared_error: 1.6400
# Epoch 66/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.5804 - y1_output_loss: 1.0002 - y2_output_loss: 2.6132 - y1_output_root_mean_squared_error: 0.9977 - y2_output_root_mean_squared_error: 1.6078 - val_loss: 11.9467 - val_y1_output_loss: 3.2728 - val_y2_output_loss: 8.6508 - val_y1_output_root_mean_squared_error: 1.8392 - val_y2_output_root_mean_squared_error: 2.9264
# Epoch 67/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.7142 - y1_output_loss: 0.9374 - y2_output_loss: 2.8014 - y1_output_root_mean_squared_error: 0.9690 - y2_output_root_mean_squared_error: 1.6659 - val_loss: 6.5497 - val_y1_output_loss: 1.9106 - val_y2_output_loss: 4.4808 - val_y1_output_root_mean_squared_error: 1.4001 - val_y2_output_root_mean_squared_error: 2.1423
# Epoch 68/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.6980 - y1_output_loss: 0.8972 - y2_output_loss: 2.7931 - y1_output_root_mean_squared_error: 0.9475 - y2_output_root_mean_squared_error: 1.6734 - val_loss: 3.5437 - val_y1_output_loss: 1.0270 - val_y2_output_loss: 2.5312 - val_y1_output_root_mean_squared_error: 1.0208 - val_y2_output_root_mean_squared_error: 1.5817
# Epoch 69/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.9459 - y1_output_loss: 0.9188 - y2_output_loss: 3.0096 - y1_output_root_mean_squared_error: 0.9579 - y2_output_root_mean_squared_error: 1.7402 - val_loss: 5.3343 - val_y1_output_loss: 1.4417 - val_y2_output_loss: 3.8891 - val_y1_output_root_mean_squared_error: 1.2223 - val_y2_output_root_mean_squared_error: 1.9597
# Epoch 70/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.1840 - y1_output_loss: 1.0268 - y2_output_loss: 3.1559 - y1_output_root_mean_squared_error: 1.0116 - y2_output_root_mean_squared_error: 1.7778 - val_loss: 4.6540 - val_y1_output_loss: 1.3144 - val_y2_output_loss: 3.2406 - val_y1_output_root_mean_squared_error: 1.1577 - val_y2_output_root_mean_squared_error: 1.8204
# Epoch 71/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.0636 - y1_output_loss: 1.0942 - y2_output_loss: 2.9484 - y1_output_root_mean_squared_error: 1.0485 - y2_output_root_mean_squared_error: 1.7217 - val_loss: 4.1443 - val_y1_output_loss: 0.9440 - val_y2_output_loss: 3.1114 - val_y1_output_root_mean_squared_error: 0.9778 - val_y2_output_root_mean_squared_error: 1.7855
# Epoch 72/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.0976 - y1_output_loss: 0.9970 - y2_output_loss: 3.0756 - y1_output_root_mean_squared_error: 0.9982 - y2_output_root_mean_squared_error: 1.7610 - val_loss: 3.8249 - val_y1_output_loss: 0.9718 - val_y2_output_loss: 2.9029 - val_y1_output_root_mean_squared_error: 0.9845 - val_y2_output_root_mean_squared_error: 1.6898
# Epoch 73/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.6011 - y1_output_loss: 0.7529 - y2_output_loss: 2.8806 - y1_output_root_mean_squared_error: 0.8696 - y2_output_root_mean_squared_error: 1.6867 - val_loss: 8.1864 - val_y1_output_loss: 0.9334 - val_y2_output_loss: 6.9883 - val_y1_output_root_mean_squared_error: 0.9689 - val_y2_output_root_mean_squared_error: 2.6922
# Epoch 74/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.1674 - y1_output_loss: 0.7002 - y2_output_loss: 2.4803 - y1_output_root_mean_squared_error: 0.8344 - y2_output_root_mean_squared_error: 1.5720 - val_loss: 4.8067 - val_y1_output_loss: 2.0335 - val_y2_output_loss: 2.6990 - val_y1_output_root_mean_squared_error: 1.4530 - val_y2_output_root_mean_squared_error: 1.6418
# Epoch 75/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.3704 - y1_output_loss: 1.2971 - y2_output_loss: 3.0485 - y1_output_root_mean_squared_error: 1.1440 - y2_output_root_mean_squared_error: 1.7498 - val_loss: 5.9727 - val_y1_output_loss: 1.5833 - val_y2_output_loss: 4.3719 - val_y1_output_root_mean_squared_error: 1.2824 - val_y2_output_root_mean_squared_error: 2.0804
# Epoch 76/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.5407 - y1_output_loss: 0.8032 - y2_output_loss: 2.7455 - y1_output_root_mean_squared_error: 0.8857 - y2_output_root_mean_squared_error: 1.6602 - val_loss: 4.9567 - val_y1_output_loss: 0.8611 - val_y2_output_loss: 3.9421 - val_y1_output_root_mean_squared_error: 0.9406 - val_y2_output_root_mean_squared_error: 2.0179
# Epoch 77/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.3057 - y1_output_loss: 1.2857 - y2_output_loss: 3.9855 - y1_output_root_mean_squared_error: 1.1376 - y2_output_root_mean_squared_error: 2.0029 - val_loss: 7.3188 - val_y1_output_loss: 1.7184 - val_y2_output_loss: 5.5572 - val_y1_output_root_mean_squared_error: 1.3312 - val_y2_output_root_mean_squared_error: 2.3552
# Epoch 78/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.9205 - y1_output_loss: 1.6909 - y2_output_loss: 4.1809 - y1_output_root_mean_squared_error: 1.3049 - y2_output_root_mean_squared_error: 2.0537 - val_loss: 3.4047 - val_y1_output_loss: 0.8828 - val_y2_output_loss: 2.4771 - val_y1_output_root_mean_squared_error: 0.9500 - val_y2_output_root_mean_squared_error: 1.5818
# Epoch 79/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.0404 - y1_output_loss: 0.9366 - y2_output_loss: 3.0932 - y1_output_root_mean_squared_error: 0.9689 - y2_output_root_mean_squared_error: 1.7611 - val_loss: 3.6564 - val_y1_output_loss: 1.3624 - val_y2_output_loss: 2.2885 - val_y1_output_root_mean_squared_error: 1.1845 - val_y2_output_root_mean_squared_error: 1.5011
# Epoch 80/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.1337 - y1_output_loss: 0.9570 - y2_output_loss: 3.1582 - y1_output_root_mean_squared_error: 0.9773 - y2_output_root_mean_squared_error: 1.7829 - val_loss: 4.8627 - val_y1_output_loss: 1.5335 - val_y2_output_loss: 3.3797 - val_y1_output_root_mean_squared_error: 1.2526 - val_y2_output_root_mean_squared_error: 1.8148
# Epoch 81/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.9094 - y1_output_loss: 0.6998 - y2_output_loss: 2.2173 - y1_output_root_mean_squared_error: 0.8388 - y2_output_root_mean_squared_error: 1.4852 - val_loss: 11.7173 - val_y1_output_loss: 2.5494 - val_y2_output_loss: 9.0543 - val_y1_output_root_mean_squared_error: 1.6271 - val_y2_output_root_mean_squared_error: 3.0116
# Epoch 82/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.0687 - y1_output_loss: 1.0393 - y2_output_loss: 3.0018 - y1_output_root_mean_squared_error: 1.0215 - y2_output_root_mean_squared_error: 1.7393 - val_loss: 3.5155 - val_y1_output_loss: 0.9496 - val_y2_output_loss: 2.5273 - val_y1_output_root_mean_squared_error: 0.9822 - val_y2_output_root_mean_squared_error: 1.5971
# Epoch 83/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.0666 - y1_output_loss: 1.0461 - y2_output_loss: 3.0027 - y1_output_root_mean_squared_error: 1.0228 - y2_output_root_mean_squared_error: 1.7379 - val_loss: 3.6471 - val_y1_output_loss: 0.8235 - val_y2_output_loss: 2.8242 - val_y1_output_root_mean_squared_error: 0.9113 - val_y2_output_root_mean_squared_error: 1.6783
# Epoch 84/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.1995 - y1_output_loss: 0.8181 - y2_output_loss: 2.4262 - y1_output_root_mean_squared_error: 0.9066 - y2_output_root_mean_squared_error: 1.5419 - val_loss: 12.4112 - val_y1_output_loss: 2.0719 - val_y2_output_loss: 10.3370 - val_y1_output_root_mean_squared_error: 1.4657 - val_y2_output_root_mean_squared_error: 3.2036
# Epoch 85/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.7786 - y1_output_loss: 0.7639 - y2_output_loss: 3.0362 - y1_output_root_mean_squared_error: 0.8758 - y2_output_root_mean_squared_error: 1.7354 - val_loss: 3.3335 - val_y1_output_loss: 0.8651 - val_y2_output_loss: 2.4846 - val_y1_output_root_mean_squared_error: 0.9433 - val_y2_output_root_mean_squared_error: 1.5632
# Epoch 86/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.8935 - y1_output_loss: 0.7576 - y2_output_loss: 2.1414 - y1_output_root_mean_squared_error: 0.8624 - y2_output_root_mean_squared_error: 1.4662 - val_loss: 4.8587 - val_y1_output_loss: 0.9017 - val_y2_output_loss: 3.8089 - val_y1_output_root_mean_squared_error: 0.9602 - val_y2_output_root_mean_squared_error: 1.9841
# Epoch 87/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.7959 - y1_output_loss: 1.0036 - y2_output_loss: 2.7764 - y1_output_root_mean_squared_error: 0.9985 - y2_output_root_mean_squared_error: 1.6730 - val_loss: 3.0946 - val_y1_output_loss: 0.7529 - val_y2_output_loss: 2.3698 - val_y1_output_root_mean_squared_error: 0.8807 - val_y2_output_root_mean_squared_error: 1.5228
# Epoch 88/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.5003 - y1_output_loss: 0.5740 - y2_output_loss: 1.9210 - y1_output_root_mean_squared_error: 0.7600 - y2_output_root_mean_squared_error: 1.3866 - val_loss: 2.8822 - val_y1_output_loss: 0.6543 - val_y2_output_loss: 2.2391 - val_y1_output_root_mean_squared_error: 0.8210 - val_y2_output_root_mean_squared_error: 1.4860
# Epoch 89/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.5224 - y1_output_loss: 1.0353 - y2_output_loss: 3.4863 - y1_output_root_mean_squared_error: 1.0202 - y2_output_root_mean_squared_error: 1.8659 - val_loss: 10.7014 - val_y1_output_loss: 2.1639 - val_y2_output_loss: 8.5219 - val_y1_output_root_mean_squared_error: 1.4961 - val_y2_output_root_mean_squared_error: 2.9092
# Epoch 90/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.0987 - y1_output_loss: 0.7191 - y2_output_loss: 2.3722 - y1_output_root_mean_squared_error: 0.8475 - y2_output_root_mean_squared_error: 1.5429 - val_loss: 5.0192 - val_y1_output_loss: 1.7174 - val_y2_output_loss: 3.2529 - val_y1_output_root_mean_squared_error: 1.3327 - val_y2_output_root_mean_squared_error: 1.8008
# Epoch 91/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.5489 - y1_output_loss: 0.6314 - y2_output_loss: 1.9111 - y1_output_root_mean_squared_error: 0.7933 - y2_output_root_mean_squared_error: 1.3855 - val_loss: 4.5636 - val_y1_output_loss: 1.3286 - val_y2_output_loss: 3.2106 - val_y1_output_root_mean_squared_error: 1.1741 - val_y2_output_root_mean_squared_error: 1.7847
# Epoch 92/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.5366 - y1_output_loss: 0.8906 - y2_output_loss: 2.6388 - y1_output_root_mean_squared_error: 0.9446 - y2_output_root_mean_squared_error: 1.6261 - val_loss: 5.6163 - val_y1_output_loss: 1.2880 - val_y2_output_loss: 4.2992 - val_y1_output_root_mean_squared_error: 1.1541 - val_y2_output_root_mean_squared_error: 2.0699
# Epoch 93/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.7042 - y1_output_loss: 0.6465 - y2_output_loss: 2.0647 - y1_output_root_mean_squared_error: 0.8064 - y2_output_root_mean_squared_error: 1.4332 - val_loss: 2.6545 - val_y1_output_loss: 0.5512 - val_y2_output_loss: 2.1380 - val_y1_output_root_mean_squared_error: 0.7524 - val_y2_output_root_mean_squared_error: 1.4451
# Epoch 94/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.1088 - y1_output_loss: 0.6741 - y2_output_loss: 2.4096 - y1_output_root_mean_squared_error: 0.8230 - y2_output_root_mean_squared_error: 1.5593 - val_loss: 2.7205 - val_y1_output_loss: 0.5924 - val_y2_output_loss: 2.1576 - val_y1_output_root_mean_squared_error: 0.7825 - val_y2_output_root_mean_squared_error: 1.4520
# Epoch 95/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.5375 - y1_output_loss: 0.5891 - y2_output_loss: 1.9436 - y1_output_root_mean_squared_error: 0.7697 - y2_output_root_mean_squared_error: 1.3946 - val_loss: 4.3835 - val_y1_output_loss: 0.7729 - val_y2_output_loss: 3.6789 - val_y1_output_root_mean_squared_error: 0.8932 - val_y2_output_root_mean_squared_error: 1.8936
# Epoch 96/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.7499 - y1_output_loss: 0.6150 - y2_output_loss: 2.1149 - y1_output_root_mean_squared_error: 0.7870 - y2_output_root_mean_squared_error: 1.4596 - val_loss: 6.6376 - val_y1_output_loss: 1.6986 - val_y2_output_loss: 4.7431 - val_y1_output_root_mean_squared_error: 1.3085 - val_y2_output_root_mean_squared_error: 2.2193
# Epoch 97/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.7323 - y1_output_loss: 1.1747 - y2_output_loss: 3.5973 - y1_output_root_mean_squared_error: 1.0820 - y2_output_root_mean_squared_error: 1.8873 - val_loss: 6.1946 - val_y1_output_loss: 1.9498 - val_y2_output_loss: 4.2174 - val_y1_output_root_mean_squared_error: 1.4202 - val_y2_output_root_mean_squared_error: 2.0439
# Epoch 98/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.7561 - y1_output_loss: 0.7295 - y2_output_loss: 2.1231 - y1_output_root_mean_squared_error: 0.8300 - y2_output_root_mean_squared_error: 1.4377 - val_loss: 14.1333 - val_y1_output_loss: 2.3028 - val_y2_output_loss: 11.7209 - val_y1_output_root_mean_squared_error: 1.5457 - val_y2_output_root_mean_squared_error: 3.4270
# Epoch 99/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.2492 - y1_output_loss: 0.7888 - y2_output_loss: 2.4393 - y1_output_root_mean_squared_error: 0.8919 - y2_output_root_mean_squared_error: 1.5665 - val_loss: 4.7905 - val_y1_output_loss: 1.5638 - val_y2_output_loss: 3.1205 - val_y1_output_root_mean_squared_error: 1.2705 - val_y2_output_root_mean_squared_error: 1.7823
# Epoch 100/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.5189 - y1_output_loss: 0.6987 - y2_output_loss: 2.8075 - y1_output_root_mean_squared_error: 0.8374 - y2_output_root_mean_squared_error: 1.6786 - val_loss: 3.3678 - val_y1_output_loss: 0.9581 - val_y2_output_loss: 2.3916 - val_y1_output_root_mean_squared_error: 0.9879 - val_y2_output_root_mean_squared_error: 1.5466
# Epoch 101/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.7534 - y1_output_loss: 0.7237 - y2_output_loss: 2.0121 - y1_output_root_mean_squared_error: 0.8537 - y2_output_root_mean_squared_error: 1.4229 - val_loss: 4.0590 - val_y1_output_loss: 0.7389 - val_y2_output_loss: 3.3396 - val_y1_output_root_mean_squared_error: 0.8715 - val_y2_output_root_mean_squared_error: 1.8165
# Epoch 102/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.7914 - y1_output_loss: 0.6765 - y2_output_loss: 2.1148 - y1_output_root_mean_squared_error: 0.8232 - y2_output_root_mean_squared_error: 1.4538 - val_loss: 2.5637 - val_y1_output_loss: 0.5748 - val_y2_output_loss: 1.9985 - val_y1_output_root_mean_squared_error: 0.7563 - val_y2_output_root_mean_squared_error: 1.4113
# Epoch 103/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.1464 - y1_output_loss: 0.4497 - y2_output_loss: 1.6863 - y1_output_root_mean_squared_error: 0.6728 - y2_output_root_mean_squared_error: 1.3014 - val_loss: 2.7316 - val_y1_output_loss: 0.6369 - val_y2_output_loss: 2.0690 - val_y1_output_root_mean_squared_error: 0.8070 - val_y2_output_root_mean_squared_error: 1.4424
# Epoch 104/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.5062 - y1_output_loss: 0.5380 - y2_output_loss: 1.9569 - y1_output_root_mean_squared_error: 0.7350 - y2_output_root_mean_squared_error: 1.4021 - val_loss: 2.5430 - val_y1_output_loss: 0.6357 - val_y2_output_loss: 1.8879 - val_y1_output_root_mean_squared_error: 0.7988 - val_y2_output_root_mean_squared_error: 1.3802
# Epoch 105/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.5760 - y1_output_loss: 0.6220 - y2_output_loss: 1.9354 - y1_output_root_mean_squared_error: 0.7916 - y2_output_root_mean_squared_error: 1.3962 - val_loss: 3.3027 - val_y1_output_loss: 0.8366 - val_y2_output_loss: 2.4697 - val_y1_output_root_mean_squared_error: 0.9300 - val_y2_output_root_mean_squared_error: 1.5614
# Epoch 106/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.7808 - y1_output_loss: 0.6713 - y2_output_loss: 2.0905 - y1_output_root_mean_squared_error: 0.8219 - y2_output_root_mean_squared_error: 1.4510 - val_loss: 3.8412 - val_y1_output_loss: 0.9100 - val_y2_output_loss: 2.8389 - val_y1_output_root_mean_squared_error: 0.9572 - val_y2_output_root_mean_squared_error: 1.7103
# Epoch 107/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.5706 - y1_output_loss: 0.5979 - y2_output_loss: 1.9535 - y1_output_root_mean_squared_error: 0.7751 - y2_output_root_mean_squared_error: 1.4035 - val_loss: 2.6353 - val_y1_output_loss: 0.6138 - val_y2_output_loss: 1.9874 - val_y1_output_root_mean_squared_error: 0.7942 - val_y2_output_root_mean_squared_error: 1.4158
# Epoch 108/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.0427 - y1_output_loss: 0.4421 - y2_output_loss: 1.5849 - y1_output_root_mean_squared_error: 0.6673 - y2_output_root_mean_squared_error: 1.2639 - val_loss: 2.7013 - val_y1_output_loss: 0.5589 - val_y2_output_loss: 2.0985 - val_y1_output_root_mean_squared_error: 0.7565 - val_y2_output_root_mean_squared_error: 1.4591
# Epoch 109/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.3582 - y1_output_loss: 0.5797 - y2_output_loss: 1.7882 - y1_output_root_mean_squared_error: 0.7559 - y2_output_root_mean_squared_error: 1.3367 - val_loss: 7.2386 - val_y1_output_loss: 1.8624 - val_y2_output_loss: 5.1560 - val_y1_output_root_mean_squared_error: 1.3788 - val_y2_output_root_mean_squared_error: 2.3103
# Epoch 110/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.1466 - y1_output_loss: 0.9514 - y2_output_loss: 3.2163 - y1_output_root_mean_squared_error: 0.9770 - y2_output_root_mean_squared_error: 1.7866 - val_loss: 10.0595 - val_y1_output_loss: 2.9804 - val_y2_output_loss: 6.9749 - val_y1_output_root_mean_squared_error: 1.7576 - val_y2_output_root_mean_squared_error: 2.6402
# Epoch 111/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.3627 - y1_output_loss: 0.7441 - y2_output_loss: 2.6342 - y1_output_root_mean_squared_error: 0.8648 - y2_output_root_mean_squared_error: 1.6170 - val_loss: 4.1469 - val_y1_output_loss: 0.9268 - val_y2_output_loss: 3.2697 - val_y1_output_root_mean_squared_error: 0.9786 - val_y2_output_root_mean_squared_error: 1.7858
# Epoch 112/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.9262 - y1_output_loss: 1.1297 - y2_output_loss: 3.7684 - y1_output_root_mean_squared_error: 1.0664 - y2_output_root_mean_squared_error: 1.9465 - val_loss: 3.4849 - val_y1_output_loss: 0.9347 - val_y2_output_loss: 2.4568 - val_y1_output_root_mean_squared_error: 0.9794 - val_y2_output_root_mean_squared_error: 1.5893
# Epoch 113/500
# 614/614 [==============================] - 0s 127us/sample - loss: 1.9732 - y1_output_loss: 0.4657 - y2_output_loss: 1.6170 - y1_output_root_mean_squared_error: 0.6704 - y2_output_root_mean_squared_error: 1.2344 - val_loss: 22.5434 - val_y1_output_loss: 3.2191 - val_y2_output_loss: 19.1646 - val_y1_output_root_mean_squared_error: 1.8246 - val_y2_output_root_mean_squared_error: 4.3834
# Epoch 114/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.3020 - y1_output_loss: 0.6944 - y2_output_loss: 2.5884 - y1_output_root_mean_squared_error: 0.8357 - y2_output_root_mean_squared_error: 1.6136 - val_loss: 2.8138 - val_y1_output_loss: 0.4815 - val_y2_output_loss: 2.3732 - val_y1_output_root_mean_squared_error: 0.6998 - val_y2_output_root_mean_squared_error: 1.5245
# Epoch 115/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.1301 - y1_output_loss: 0.4696 - y2_output_loss: 1.6564 - y1_output_root_mean_squared_error: 0.6858 - y2_output_root_mean_squared_error: 1.2883 - val_loss: 3.4086 - val_y1_output_loss: 0.6470 - val_y2_output_loss: 2.7653 - val_y1_output_root_mean_squared_error: 0.8167 - val_y2_output_root_mean_squared_error: 1.6558
# Epoch 116/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.3665 - y1_output_loss: 0.5582 - y2_output_loss: 1.8060 - y1_output_root_mean_squared_error: 0.7473 - y2_output_root_mean_squared_error: 1.3446 - val_loss: 7.5318 - val_y1_output_loss: 2.9622 - val_y2_output_loss: 4.4778 - val_y1_output_root_mean_squared_error: 1.7501 - val_y2_output_root_mean_squared_error: 2.1140
# Epoch 117/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.4225 - y1_output_loss: 0.5963 - y2_output_loss: 1.8094 - y1_output_root_mean_squared_error: 0.7757 - y2_output_root_mean_squared_error: 1.3494 - val_loss: 2.8533 - val_y1_output_loss: 0.7014 - val_y2_output_loss: 2.1639 - val_y1_output_root_mean_squared_error: 0.8489 - val_y2_output_root_mean_squared_error: 1.4604
# Epoch 118/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.0310 - y1_output_loss: 0.4479 - y2_output_loss: 1.5873 - y1_output_root_mean_squared_error: 0.6662 - y2_output_root_mean_squared_error: 1.2599 - val_loss: 3.9516 - val_y1_output_loss: 0.9265 - val_y2_output_loss: 3.0491 - val_y1_output_root_mean_squared_error: 0.9739 - val_y2_output_root_mean_squared_error: 1.7330
# Epoch 119/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.2204 - y1_output_loss: 0.5401 - y2_output_loss: 1.6690 - y1_output_root_mean_squared_error: 0.7360 - y2_output_root_mean_squared_error: 1.2956 - val_loss: 2.6474 - val_y1_output_loss: 0.7508 - val_y2_output_loss: 1.8537 - val_y1_output_root_mean_squared_error: 0.8803 - val_y2_output_root_mean_squared_error: 1.3684
# Epoch 120/500
# 614/614 [==============================] - 0s 132us/sample - loss: 1.8095 - y1_output_loss: 0.3995 - y2_output_loss: 1.4084 - y1_output_root_mean_squared_error: 0.6319 - y2_output_root_mean_squared_error: 1.1875 - val_loss: 2.2699 - val_y1_output_loss: 0.3931 - val_y2_output_loss: 1.8987 - val_y1_output_root_mean_squared_error: 0.6338 - val_y2_output_root_mean_squared_error: 1.3668
# ...
# Epoch 407/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.5305 - y1_output_loss: 0.1205 - y2_output_loss: 0.4072 - y1_output_root_mean_squared_error: 0.3485 - y2_output_root_mean_squared_error: 0.6396 - val_loss: 1.3200 - val_y1_output_loss: 0.3076 - val_y2_output_loss: 1.0100 - val_y1_output_root_mean_squared_error: 0.5642 - val_y2_output_root_mean_squared_error: 1.0008
# Epoch 408/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4511 - y1_output_loss: 0.1300 - y2_output_loss: 0.3210 - y1_output_root_mean_squared_error: 0.3610 - y2_output_root_mean_squared_error: 0.5664 - val_loss: 0.7275 - val_y1_output_loss: 0.2780 - val_y2_output_loss: 0.4439 - val_y1_output_root_mean_squared_error: 0.5333 - val_y2_output_root_mean_squared_error: 0.6657
# Epoch 409/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4224 - y1_output_loss: 0.1112 - y2_output_loss: 0.3130 - y1_output_root_mean_squared_error: 0.3345 - y2_output_root_mean_squared_error: 0.5573 - val_loss: 0.9872 - val_y1_output_loss: 0.3032 - val_y2_output_loss: 0.6802 - val_y1_output_root_mean_squared_error: 0.5591 - val_y2_output_root_mean_squared_error: 0.8214
# Epoch 410/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.5313 - y1_output_loss: 0.1374 - y2_output_loss: 0.4003 - y1_output_root_mean_squared_error: 0.3720 - y2_output_root_mean_squared_error: 0.6269 - val_loss: 1.3910 - val_y1_output_loss: 0.3252 - val_y2_output_loss: 1.0723 - val_y1_output_root_mean_squared_error: 0.5780 - val_y2_output_root_mean_squared_error: 1.0281
# Epoch 411/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.5641 - y1_output_loss: 0.1440 - y2_output_loss: 0.4178 - y1_output_root_mean_squared_error: 0.3795 - y2_output_root_mean_squared_error: 0.6482 - val_loss: 0.8078 - val_y1_output_loss: 0.3155 - val_y2_output_loss: 0.4872 - val_y1_output_root_mean_squared_error: 0.5710 - val_y2_output_root_mean_squared_error: 0.6940
# Epoch 412/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4799 - y1_output_loss: 0.1301 - y2_output_loss: 0.3513 - y1_output_root_mean_squared_error: 0.3619 - y2_output_root_mean_squared_error: 0.5907 - val_loss: 2.6306 - val_y1_output_loss: 0.4351 - val_y2_output_loss: 2.1245 - val_y1_output_root_mean_squared_error: 0.6641 - val_y2_output_root_mean_squared_error: 1.4797
# Epoch 413/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4420 - y1_output_loss: 0.1297 - y2_output_loss: 0.3098 - y1_output_root_mean_squared_error: 0.3611 - y2_output_root_mean_squared_error: 0.5582 - val_loss: 0.9918 - val_y1_output_loss: 0.3706 - val_y2_output_loss: 0.6136 - val_y1_output_root_mean_squared_error: 0.6196 - val_y2_output_root_mean_squared_error: 0.7796
# Epoch 414/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4415 - y1_output_loss: 0.1355 - y2_output_loss: 0.3021 - y1_output_root_mean_squared_error: 0.3696 - y2_output_root_mean_squared_error: 0.5522 - val_loss: 0.7404 - val_y1_output_loss: 0.2617 - val_y2_output_loss: 0.4679 - val_y1_output_root_mean_squared_error: 0.5190 - val_y2_output_root_mean_squared_error: 0.6863
# Epoch 415/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3962 - y1_output_loss: 0.1198 - y2_output_loss: 0.2744 - y1_output_root_mean_squared_error: 0.3473 - y2_output_root_mean_squared_error: 0.5250 - val_loss: 0.7558 - val_y1_output_loss: 0.2608 - val_y2_output_loss: 0.4858 - val_y1_output_root_mean_squared_error: 0.5161 - val_y2_output_root_mean_squared_error: 0.6996
# Epoch 416/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4754 - y1_output_loss: 0.1471 - y2_output_loss: 0.3248 - y1_output_root_mean_squared_error: 0.3842 - y2_output_root_mean_squared_error: 0.5725 - val_loss: 0.9458 - val_y1_output_loss: 0.3877 - val_y2_output_loss: 0.5467 - val_y1_output_root_mean_squared_error: 0.6340 - val_y2_output_root_mean_squared_error: 0.7374
# Epoch 417/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3566 - y1_output_loss: 0.1080 - y2_output_loss: 0.2481 - y1_output_root_mean_squared_error: 0.3298 - y2_output_root_mean_squared_error: 0.4978 - val_loss: 0.7444 - val_y1_output_loss: 0.2766 - val_y2_output_loss: 0.4653 - val_y1_output_root_mean_squared_error: 0.5332 - val_y2_output_root_mean_squared_error: 0.6784
# Epoch 418/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4665 - y1_output_loss: 0.1226 - y2_output_loss: 0.3417 - y1_output_root_mean_squared_error: 0.3512 - y2_output_root_mean_squared_error: 0.5858 - val_loss: 0.8361 - val_y1_output_loss: 0.2915 - val_y2_output_loss: 0.5416 - val_y1_output_root_mean_squared_error: 0.5485 - val_y2_output_root_mean_squared_error: 0.7316
# Epoch 419/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.5897 - y1_output_loss: 0.1502 - y2_output_loss: 0.4395 - y1_output_root_mean_squared_error: 0.3879 - y2_output_root_mean_squared_error: 0.6627 - val_loss: 1.3055 - val_y1_output_loss: 0.4880 - val_y2_output_loss: 0.8068 - val_y1_output_root_mean_squared_error: 0.7108 - val_y2_output_root_mean_squared_error: 0.8946
# Epoch 420/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4342 - y1_output_loss: 0.1264 - y2_output_loss: 0.3112 - y1_output_root_mean_squared_error: 0.3519 - y2_output_root_mean_squared_error: 0.5571 - val_loss: 0.9767 - val_y1_output_loss: 0.3933 - val_y2_output_loss: 0.5932 - val_y1_output_root_mean_squared_error: 0.6258 - val_y2_output_root_mean_squared_error: 0.7649
# Epoch 421/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.5060 - y1_output_loss: 0.1560 - y2_output_loss: 0.3486 - y1_output_root_mean_squared_error: 0.3939 - y2_output_root_mean_squared_error: 0.5923 - val_loss: 0.9324 - val_y1_output_loss: 0.2410 - val_y2_output_loss: 0.6653 - val_y1_output_root_mean_squared_error: 0.4982 - val_y2_output_root_mean_squared_error: 0.8272
# Epoch 422/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3758 - y1_output_loss: 0.1198 - y2_output_loss: 0.2555 - y1_output_root_mean_squared_error: 0.3456 - y2_output_root_mean_squared_error: 0.5063 - val_loss: 0.7772 - val_y1_output_loss: 0.2528 - val_y2_output_loss: 0.5080 - val_y1_output_root_mean_squared_error: 0.5095 - val_y2_output_root_mean_squared_error: 0.7195
# Epoch 423/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4712 - y1_output_loss: 0.1381 - y2_output_loss: 0.3331 - y1_output_root_mean_squared_error: 0.3681 - y2_output_root_mean_squared_error: 0.5794 - val_loss: 1.0709 - val_y1_output_loss: 0.4408 - val_y2_output_loss: 0.6091 - val_y1_output_root_mean_squared_error: 0.6763 - val_y2_output_root_mean_squared_error: 0.7833
# Epoch 424/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3836 - y1_output_loss: 0.1187 - y2_output_loss: 0.2643 - y1_output_root_mean_squared_error: 0.3436 - y2_output_root_mean_squared_error: 0.5153 - val_loss: 0.8118 - val_y1_output_loss: 0.2632 - val_y2_output_loss: 0.5324 - val_y1_output_root_mean_squared_error: 0.5167 - val_y2_output_root_mean_squared_error: 0.7381
# Epoch 425/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3532 - y1_output_loss: 0.1083 - y2_output_loss: 0.2424 - y1_output_root_mean_squared_error: 0.3300 - y2_output_root_mean_squared_error: 0.4943 - val_loss: 1.2420 - val_y1_output_loss: 0.3389 - val_y2_output_loss: 0.8924 - val_y1_output_root_mean_squared_error: 0.5920 - val_y2_output_root_mean_squared_error: 0.9442
# Epoch 426/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3924 - y1_output_loss: 0.1146 - y2_output_loss: 0.2760 - y1_output_root_mean_squared_error: 0.3399 - y2_output_root_mean_squared_error: 0.5261 - val_loss: 0.7477 - val_y1_output_loss: 0.2709 - val_y2_output_loss: 0.4740 - val_y1_output_root_mean_squared_error: 0.5273 - val_y2_output_root_mean_squared_error: 0.6853
# Epoch 427/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3683 - y1_output_loss: 0.1230 - y2_output_loss: 0.2449 - y1_output_root_mean_squared_error: 0.3508 - y2_output_root_mean_squared_error: 0.4952 - val_loss: 1.2833 - val_y1_output_loss: 0.4836 - val_y2_output_loss: 0.7896 - val_y1_output_root_mean_squared_error: 0.7067 - val_y2_output_root_mean_squared_error: 0.8854
# Epoch 428/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4395 - y1_output_loss: 0.1297 - y2_output_loss: 0.3213 - y1_output_root_mean_squared_error: 0.3572 - y2_output_root_mean_squared_error: 0.5585 - val_loss: 2.6464 - val_y1_output_loss: 0.6919 - val_y2_output_loss: 2.0195 - val_y1_output_root_mean_squared_error: 0.8296 - val_y2_output_root_mean_squared_error: 1.3993
# Epoch 429/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4804 - y1_output_loss: 0.1310 - y2_output_loss: 0.3487 - y1_output_root_mean_squared_error: 0.3603 - y2_output_root_mean_squared_error: 0.5921 - val_loss: 1.1864 - val_y1_output_loss: 0.4217 - val_y2_output_loss: 0.7332 - val_y1_output_root_mean_squared_error: 0.6555 - val_y2_output_root_mean_squared_error: 0.8699
# Epoch 430/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3912 - y1_output_loss: 0.1357 - y2_output_loss: 0.2583 - y1_output_root_mean_squared_error: 0.3664 - y2_output_root_mean_squared_error: 0.5069 - val_loss: 2.0994 - val_y1_output_loss: 0.6499 - val_y2_output_loss: 1.4355 - val_y1_output_root_mean_squared_error: 0.8202 - val_y2_output_root_mean_squared_error: 1.1944
# Epoch 431/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.5423 - y1_output_loss: 0.1627 - y2_output_loss: 0.3772 - y1_output_root_mean_squared_error: 0.4029 - y2_output_root_mean_squared_error: 0.6164 - val_loss: 0.8451 - val_y1_output_loss: 0.3003 - val_y2_output_loss: 0.5271 - val_y1_output_root_mean_squared_error: 0.5523 - val_y2_output_root_mean_squared_error: 0.7349
# Epoch 432/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4690 - y1_output_loss: 0.1343 - y2_output_loss: 0.3401 - y1_output_root_mean_squared_error: 0.3677 - y2_output_root_mean_squared_error: 0.5777 - val_loss: 1.4974 - val_y1_output_loss: 0.3002 - val_y2_output_loss: 1.2112 - val_y1_output_root_mean_squared_error: 0.5580 - val_y2_output_root_mean_squared_error: 1.0891
# Epoch 433/500
# 614/614 [==============================] - 0s 128us/sample - loss: 1.0267 - y1_output_loss: 0.2685 - y2_output_loss: 0.7487 - y1_output_root_mean_squared_error: 0.5205 - y2_output_root_mean_squared_error: 0.8694 - val_loss: 0.8471 - val_y1_output_loss: 0.2864 - val_y2_output_loss: 0.5480 - val_y1_output_root_mean_squared_error: 0.5385 - val_y2_output_root_mean_squared_error: 0.7464
# Epoch 434/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3348 - y1_output_loss: 0.1061 - y2_output_loss: 0.2418 - y1_output_root_mean_squared_error: 0.3258 - y2_output_root_mean_squared_error: 0.4783 - val_loss: 4.7790 - val_y1_output_loss: 0.4014 - val_y2_output_loss: 4.3413 - val_y1_output_root_mean_squared_error: 0.6449 - val_y2_output_root_mean_squared_error: 2.0888
# Epoch 435/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4600 - y1_output_loss: 0.1246 - y2_output_loss: 0.3421 - y1_output_root_mean_squared_error: 0.3535 - y2_output_root_mean_squared_error: 0.5788 - val_loss: 3.1119 - val_y1_output_loss: 0.5369 - val_y2_output_loss: 2.4865 - val_y1_output_root_mean_squared_error: 0.7386 - val_y2_output_root_mean_squared_error: 1.6020
# Epoch 436/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4031 - y1_output_loss: 0.1209 - y2_output_loss: 0.2800 - y1_output_root_mean_squared_error: 0.3473 - y2_output_root_mean_squared_error: 0.5314 - val_loss: 0.8125 - val_y1_output_loss: 0.2667 - val_y2_output_loss: 0.5432 - val_y1_output_root_mean_squared_error: 0.5233 - val_y2_output_root_mean_squared_error: 0.7340
# Epoch 437/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3487 - y1_output_loss: 0.1055 - y2_output_loss: 0.2426 - y1_output_root_mean_squared_error: 0.3249 - y2_output_root_mean_squared_error: 0.4931 - val_loss: 0.9108 - val_y1_output_loss: 0.3326 - val_y2_output_loss: 0.5625 - val_y1_output_root_mean_squared_error: 0.5821 - val_y2_output_root_mean_squared_error: 0.7563
# Epoch 438/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4781 - y1_output_loss: 0.1314 - y2_output_loss: 0.3447 - y1_output_root_mean_squared_error: 0.3619 - y2_output_root_mean_squared_error: 0.5892 - val_loss: 0.8785 - val_y1_output_loss: 0.3861 - val_y2_output_loss: 0.4935 - val_y1_output_root_mean_squared_error: 0.6260 - val_y2_output_root_mean_squared_error: 0.6976
# Epoch 439/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4183 - y1_output_loss: 0.1159 - y2_output_loss: 0.2985 - y1_output_root_mean_squared_error: 0.3419 - y2_output_root_mean_squared_error: 0.5490 - val_loss: 0.8172 - val_y1_output_loss: 0.3125 - val_y2_output_loss: 0.5022 - val_y1_output_root_mean_squared_error: 0.5686 - val_y2_output_root_mean_squared_error: 0.7027
# Epoch 440/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3441 - y1_output_loss: 0.1111 - y2_output_loss: 0.2317 - y1_output_root_mean_squared_error: 0.3341 - y2_output_root_mean_squared_error: 0.4822 - val_loss: 0.7936 - val_y1_output_loss: 0.2596 - val_y2_output_loss: 0.5176 - val_y1_output_root_mean_squared_error: 0.5159 - val_y2_output_root_mean_squared_error: 0.7263
# Epoch 441/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4154 - y1_output_loss: 0.1184 - y2_output_loss: 0.2957 - y1_output_root_mean_squared_error: 0.3429 - y2_output_root_mean_squared_error: 0.5457 - val_loss: 0.7631 - val_y1_output_loss: 0.3288 - val_y2_output_loss: 0.4315 - val_y1_output_root_mean_squared_error: 0.5776 - val_y2_output_root_mean_squared_error: 0.6553
# Epoch 442/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.5155 - y1_output_loss: 0.1357 - y2_output_loss: 0.3829 - y1_output_root_mean_squared_error: 0.3679 - y2_output_root_mean_squared_error: 0.6166 - val_loss: 3.4037 - val_y1_output_loss: 1.1226 - val_y2_output_loss: 2.2209 - val_y1_output_root_mean_squared_error: 1.0780 - val_y2_output_root_mean_squared_error: 1.4972
# Epoch 443/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4590 - y1_output_loss: 0.1429 - y2_output_loss: 0.3165 - y1_output_root_mean_squared_error: 0.3792 - y2_output_root_mean_squared_error: 0.5614 - val_loss: 0.9387 - val_y1_output_loss: 0.2712 - val_y2_output_loss: 0.6729 - val_y1_output_root_mean_squared_error: 0.5279 - val_y2_output_root_mean_squared_error: 0.8124
# Epoch 444/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.5466 - y1_output_loss: 0.1519 - y2_output_loss: 0.3962 - y1_output_root_mean_squared_error: 0.3877 - y2_output_root_mean_squared_error: 0.6295 - val_loss: 0.8360 - val_y1_output_loss: 0.3596 - val_y2_output_loss: 0.4708 - val_y1_output_root_mean_squared_error: 0.6086 - val_y2_output_root_mean_squared_error: 0.6824
# Epoch 445/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4587 - y1_output_loss: 0.1335 - y2_output_loss: 0.3257 - y1_output_root_mean_squared_error: 0.3645 - y2_output_root_mean_squared_error: 0.5709 - val_loss: 0.7602 - val_y1_output_loss: 0.2916 - val_y2_output_loss: 0.4723 - val_y1_output_root_mean_squared_error: 0.5427 - val_y2_output_root_mean_squared_error: 0.6824
# Epoch 446/500
#  10/614 [..............................] - ETA: 0s - loss: 0.1925 - y1_output_loss: 0.0741 - y2_output_loss: 0.1184 - y1_output_root_mean_squared_error: 0.2722 - y2_output_root_mean_squared_error: 0.3441

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
